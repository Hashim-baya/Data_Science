# %%
import pandas as pd

# %%
Housing_df = pd.read_csv('../data/USA_Housing.csv')
Housing_df.head(10)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
# 5      80175.754159             4.988408                   6.104512
# 6      64698.463428             6.025336                   8.147760
# 7      78394.339278             6.989780                   6.620478
# 8      59927.660813             5.362126                   6.393121
# 9      81885.927184             4.423672                   8.167688
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# ...

# %%
Housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
Housing_df.shape
# Out:
# (5000, 7)

# %%
Housing_df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
Housing_df.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
Housing_df.duplicated().sum()
# Out:
# 0

# %%
Housing_df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
for column in Housing_df.columns :
    print(f'....Value_Counts in {column}.....: ')
    print(Housing_df[column].value_counts())
    print('\n')
# Out:
# ....Value_Counts in Avg. Area Income.....:
# Avg. Area Income
# 79545.458574    1
# 68735.436608    1
# 71635.473101    1
# 73211.136245    1
# 86249.993070    1
#                ..
# 66064.532823    1
# 59390.346824    1
# 64661.930276    1
# 73279.030904    1
# 65510.581804    1
# Name: count, Length: 5000, dtype: int64
#
#
# ....Value_Counts in Avg. Area House Age.....:
# Avg. Area House Age
# 5.682861    1
# 7.721909    1
# 5.866996    1
# 6.501139    1
# 6.155403    1
#            ..
# 6.659562    1
# 5.664971    1
# 4.656696    1
# 5.902296    1
# 5.992305    1
# Name: count, Length: 5000, dtype: int64
#
#
# ....Value_Counts in Avg. Area Number of Rooms.....:
# Avg. Area Number of Rooms
# 7.009188     1
# 7.621975     1
# 6.075987     1
# 10.280022    1
# 7.967184     1
#             ..
# 6.881398     1
# 6.750872     1
# 5.660253     1
# 8.077578     1
# 6.792336     1
# Name: count, Length: 5000, dtype: int64
#
#
# ....Value_Counts in Avg. Area Number of Bedrooms.....:
# ...

# %%
for column in Housing_df.columns :
    print(f'....Describing {column}.....: ')
    print(Housing_df[column].describe())
    print('\n')
# Out:
# ....Describing Avg. Area Income.....:
# count      5000.000000
# mean      68583.108984
# std       10657.991214
# min       17796.631190
# 25%       61480.562388
# 50%       68804.286404
# 75%       75783.338666
# max      107701.748378
# Name: Avg. Area Income, dtype: float64
#
#
# ....Describing Avg. Area House Age.....:
# count    5000.000000
# mean        5.977222
# std         0.991456
# min         2.644304
# 25%         5.322283
# 50%         5.970429
# 75%         6.650808
# max         9.519088
# Name: Avg. Area House Age, dtype: float64
#
#
# ....Describing Avg. Area Number of Rooms.....:
# count    5000.000000
# mean        6.987792
# std         1.005833
# min         3.236194
# 25%         6.299250
# 50%         7.002902
# 75%         7.665871
# max        10.759588
# Name: Avg. Area Number of Rooms, dtype: float64
#
#
# ....Describing Avg. Area Number of Bedrooms.....:
# count    5000.000000
# mean        3.981330
# std         1.234137
# min         2.000000
# ...
