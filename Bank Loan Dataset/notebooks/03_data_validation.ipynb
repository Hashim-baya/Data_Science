# %%
import pandas as pd
pd.set_option('display.max_columns', 300)
pd.set_option('display.max_rows', 300)

# %%
bank = pd.read_csv('../data/interim/bank_data_cleaned.csv')
bank.head(10)
# Out:
#    customer_id  age  gender marital_status education_level  annual_income  \
# 0    311621071   47    Male         Single             PhD       17331.80
# 1    255253104   25    Male         Single          Master        9079.24
# 2    192841080   39    Male        Married        Bachelor       46310.23
# 3    965861027   56    Male        Married        Bachelor       48332.75
# 4    984431548   67    Male         Single        Bachelor       12383.67
# 5    324506058   32  Female         Single             PhD       35348.24
# 6    513123400   61    Male        Married        Bachelor       69649.42
# 7    487998143   56  Female        Married        Bachelor       45654.19
# 8    672263662   57  Female         Single        Bachelor      155966.74
# 9    139954149   19    Male         Single             PhD       50337.98
#
#    loan_amount  credit_score  employment_years employment_type loan_purpose  \
# 0    452629.07           682                25       Part-time     Business
# ...

# %%
bank.dtypes
# Out:
# customer_id               int64
# age                       int64
# gender                   object
# marital_status           object
# education_level          object
# annual_income           float64
# loan_amount             float64
# credit_score              int64
# employment_years          int64
# employment_type          object
# loan_purpose             object
# home_ownership           object
# debt_to_income_ratio    float64
# existing_loans            int64
# loan_term_months          int64
# interest_rate           float64
# loan_status              object
# application_date         object
# dtype: object

# %%
bank['application_date'] = pd.to_datetime(bank['application_date'])
bank.dtypes
# Out:
# customer_id                      int64
# age                              int64
# gender                          object
# marital_status                  object
# education_level                 object
# annual_income                  float64
# loan_amount                    float64
# credit_score                     int64
# employment_years                 int64
# employment_type                 object
# loan_purpose                    object
# home_ownership                  object
# debt_to_income_ratio           float64
# existing_loans                   int64
# loan_term_months                 int64
# interest_rate                  float64
# loan_status                     object
# application_date        datetime64[ns]
# dtype: object
